# %% [markdown]
# # Danny's Pizza — Dataset Scaffold (OscarF Datasets generator)
#
# > Add blockquote
#
#
#
# **Created:** 2025-08-22 00:39
#
# This notebook sets up the **small tables** in-notebook and expects the **large order tables** to be loaded from CSV/XLS files.
# It strictly follows the schema from class:
#
# - `pizza_names(pizza_id INT, pizza_name TEXT)`
# - `pizza_toppings(topping_id INT, topping_name TEXT)`
# - `pizza_recipes(pizza_id INT, toppings TEXT)` where `toppings` is a comma-separated list of `topping_id`s
# - `runners(runner_id INT, registration_date DATE)`
# - `customer_orders(order_id INT, customer_id INT, pizza_id INT, exclusions VARCHAR(4), extras VARCHAR(4), order_date TIMESTAMP)`
# - `runner_orders(order_id INT, runner_id INT, pickup_time VARCHAR(19), distance VARCHAR(7), duration VARCHAR(10), cancellation VARCHAR(23))`

# %%
import os
# Usar la carpeta local donde está el notebook
base_path = os.getcwd() + os.sep
print(f"Usando base_path local: {base_path}")
# Out:
# Usando base_path local: /content/

# %%
import pandas as pd

# %% [markdown]
# ## Create Small Tables (Dims)
#
# We define a **minimal, realistic** pizza catalog.

# %%
# --- pizza_names ---
pizza_names = pd.DataFrame({
    'pizza_id': [1, 2, 3, 4, 5, 6, 7],
    'pizza_name': [
        'Margherita',        # 1
        'Vegetarian',        # 2
        'Meat Lovers',       # 3
        'BBQ Chicken',       # 4
        'Hawaiian',          # 5
        'Pepperoni',         # 6
        'Vegan Veggie'       # 7  <-- vegan option (no cheese by default)
    ]
})
pizza_names.to_csv(base_path+'pizza_names.csv', index=False)
pizza_names
# Out:
#    pizza_id    pizza_name
# 0         1    Margherita
# 1         2    Vegetarian
# 2         3   Meat Lovers
# 3         4   BBQ Chicken
# 4         5      Hawaiian
# 5         6     Pepperoni
# 6         7  Vegan Veggie

# %%
# --- pizza_toppings ---
# Concise list so students can reason about extras/exclusions clearly
pizza_toppings = pd.DataFrame({
    'topping_id': list(range(1, 16)),
    'topping_name': [
        'Tomato Sauce',  # 1
        'Mozzarella',    # 2
        'Mushroom',      # 3
        'Onion',         # 4
        'Bell Pepper',   # 5
        'Olives',        # 6
        'Pepperoni',     # 7
        'Bacon',         # 8
        'Beef',          # 9
        'Chicken',       # 10
        'Pineapple',     # 11
        'BBQ Sauce',     # 12
        'Jalapeno',      # 13
        'Fresh Basil',   # 14
        'Garlic'         # 15
    ]
})
pizza_toppings.to_csv(base_path+'pizza_toppings.csv', index=False)
pizza_toppings
# Out:
#     topping_id  topping_name
# 0            1  Tomato Sauce
# 1            2    Mozzarella
# 2            3      Mushroom
# 3            4         Onion
# 4            5   Bell Pepper
# 5            6        Olives
# 6            7     Pepperoni
# 7            8         Bacon
# 8            9          Beef
# 9           10       Chicken
# 10          11     Pineapple
# 11          12     BBQ Sauce
# 12          13      Jalapeno
# 13          14   Fresh Basil
# 14          15        Garlic

# %%
# --- pizza_recipes ---
# Define base recipes as comma-separated topping_id strings (order does not matter)
recipes_map = {
    1: [1,2,14],               # Margherita: sauce, mozzarella, basil
    2: [1,2,3,4,5,6],          # Vegetarian: sauce, mozzarella, mushroom, onion, bell pepper, olives
    3: [1,2,7,8,9],            # Meat Lovers: sauce, mozzarella, pepperoni, bacon, beef
    4: [1,2,10,12],            # BBQ Chicken: sauce, mozzarella, chicken, bbq sauce
    5: [1,2,11,6],             # Hawaiian: sauce, mozzarella, pineapple, olives
    6: [1,2,7],                # Pepperoni: sauce, mozzarella, pepperoni
    7: [1,3,4,5,6,15]          # Vegan Veggie: sauce, mushroom, onion, bell pepper, olives, garlic (no cheese)
}

pizza_recipes = pd.DataFrame({
    'pizza_id': list(recipes_map.keys()),
    'toppings': [','.join(map(str, v)) for v in recipes_map.values()]
})
pizza_recipes.to_csv(base_path+ 'pizza_recipes.csv', index=False)
pizza_recipes
# Out:
#    pizza_id      toppings
# 0         1        1,2,14
# 1         2   1,2,3,4,5,6
# 2         3     1,2,7,8,9
# 3         4     1,2,10,12
# 4         5      1,2,11,6
# 5         6         1,2,7
# 6         7  1,3,4,5,6,15

# %%
# --- runners ---

dates = pd.date_range('2021-01-03', periods=15, freq='7D')
runners = pd.DataFrame({
    'runner_id': range(1, 16),
    'registration_date': dates.date
})
runners.to_csv(base_path+'runners.csv', index=False)
runners
# Out:
#     runner_id registration_date
# 0           1        2021-01-03
# 1           2        2021-01-10
# 2           3        2021-01-17
# 3           4        2021-01-24
# 4           5        2021-01-31
# 5           6        2021-02-07
# 6           7        2021-02-14
# 7           8        2021-02-21
# 8           9        2021-02-28
# 9          10        2021-03-07
# 10         11        2021-03-14
# 11         12        2021-03-21
# 12         13        2021-03-28
# 13         14        2021-04-04
# 14         15        2021-04-11

# %% [markdown]
# ## Load Orders
#
# This cell loads the orders from CSV first; if not present, it tries XLSX. Adjust file paths if needed.

# %%
import os

# Cargar customer_orders y runner_orders desde CSV o XLSX
def load_orders(filename_base):
    csv_path = os.path.join(base_path, filename_base + '.csv')
    xlsx_path = os.path.join(base_path, filename_base + '.xlsx')
    if os.path.exists(csv_path):
        return pd.read_csv(csv_path)
    elif os.path.exists(xlsx_path):
        return pd.read_excel(xlsx_path)
    else:
        raise FileNotFoundError(f"No se encontró {filename_base}.csv ni {filename_base}.xlsx en {base_path}")

# %% [markdown]
# ## Cleaning & Normalization Helpers
#
# - Parse `distance` (to float km) and `duration` (to minutes).
# - Normalize `cancellation` labels (lowercase, strip).
# - Enforce FK integrity and logical constraints.

# %%
import numpy as np

# Base path in Google Drive


# --- Load small dimension tables ---
pizza_names     = pd.read_csv(base_path +'pizza_names.csv')
pizza_toppings  = pd.read_csv(base_path + 'pizza_toppings.csv')
pizza_recipes   = pd.read_csv(base_path + 'pizza_recipes.csv')
runners         = pd.read_csv(base_path + 'runners.csv')

# --- Load big fact tables ---
customer_orders = pd.read_csv(base_path + 'customer_orders.csv')
runner_orders   = pd.read_csv(base_path + 'runner_orders.csv')

print("pizza_names:", pizza_names.shape)
print("pizza_toppings:", pizza_toppings.shape)
print("pizza_recipes:", pizza_recipes.shape)
print("runners:", runners.shape)
print("customer_orders:", customer_orders.shape)
print("runner_orders:", runner_orders.shape)
# Out:
# pizza_names: (7, 2)
# pizza_toppings: (15, 2)
# pizza_recipes: (7, 2)
# runners: (15, 2)
# customer_orders: (2101, 6)
# runner_orders: (1500, 6)

# %%
customer_orders.head()
# Out:
#    order_id  customer_id  pizza_id exclusions extras           order_date
# 0      2481          500         2        NaN    NaN  2025-02-21 16:06:46
# 1      1897          269         6        NaN    NaN  2025-08-12 08:27:50
# 2      1842           59         7        NaN    NaN  2024-12-23 20:50:23
# 3      1869          710         6        NaN    NaN  2025-01-31 09:16:49
# 4      2384          189         3        NaN    NaN  2024-11-30 17:35:37

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
#
# # /* --------------------
# #   Case Study Questions
# #   --------------------*/
# A. Pizza Metrics
#
#     How many pizzas were ordered?
#     How many unique customer orders were made?
#     How many successful orders were delivered by each runner?
#     How many of each type of pizza was delivered?
#     How many Vegetarian and Meatlovers were ordered by each customer?
#     What was the maximum number of pizzas delivered in a single order?
#     For each customer, how many delivered pizzas had at least 1 change and how many had no changes?
#     How many pizzas were delivered that had both exclusions and extras?
#     What was the total volume of pizzas ordered for each hour of the day?
#     What was the volume of orders for each day of the week?
#
# B. Runner and Customer Experience
#
#     How many runners signed up for each 1 week period? (i.e. week starts 2021-01-01)
#     What was the average time in minutes it took for each runner to arrive at the Pizza Runner HQ to pickup the order?
#     Is there any relationship between the number of pizzas and how long the order takes to prepare?
#     What was the average distance travelled for each customer?
#     What was the difference between the longest and shortest delivery times for all orders?
#     What was the average speed for each runner for each delivery and do you notice any trend for these values?
#     What is the successful delivery percentage for each runner?
#
# 🍕 section c — customer & business intelligence
#
# C1. total customer spend
#  which customers bring in the most revenue?
#
# use to argue for vip memberships or spend-based rewards.
#
# C2. customer frequency (distinct days of orders)
#  who orders regularly vs. one-off customers?
#
# segment into loyal customers vs. occasional customers.
#
# hint at frequency-based discounts (e.g., 5th order free).
#
# C3. first pizza ordered by each customer
#  what attracts customers initially?
#
# good to identify entry-point pizzas (the hook item that brings people in).
#
# hint at discounts on first-order pizzas to acquire new customers.
#
# C4. overall best-seller pizza
#  which pizza keeps the lights on?
#
# highlight as a flagship product to promote.
#
# use for seasonal bundles (“summer deal with our #1 pizza”).
#
# C5. most popular pizza by customer
#  can we personalize offers?
#
# recommend personalized “customer favorites” discounts.
#
# hint toward AI/BI-driven recommender systems.
#
# C6. regulars with ≥30 orders and their go-to pizzas
#  who are the heavy hitters and what do they like?
#
# obvious loyalty program candidates.
#
# pitch: “keep them happy with exclusive rewards so they don’t churn.”
#
# C7. customers with very consistent habits (always order the same pizza)
#  creatures of habit = stable recurring revenue.
#
# membership idea: “pizza subscription” (weekly plan with their pizza auto-delivered).
#
# C8. the “perfect pair”
#
# great marketing story: “find your pizza soulmate.”
#
# pitch: social media campaign + 2-for-1  perfect pizza couples’ promo.
#
# C9. peak order times
# 👉 what hours & days matter most?
#
# operational: staff scheduling.
#
# marketing: happy hour discounts in slow periods, premium pricing at peak times.
#
# C10. best candidates for loyalty program
# 👉 combine spend + frequency + consistency.
#
# identify top 5–10% customers.
#
# suggest tiered memberships: silver/gold/platinum.
#
# seasonal perks: double points in winter when sales slow.
#
# # Entregable
#
# final presentation = a business intelligence pitch deck:
#
# customer segmentation (loyal vs occasional vs perfect pair).
#
# menu insights (flagship pizza, first-order hook, personal favorites).
#
# time insights (peak hours, seasonal discounts).
#
# strategic recommendations:
#
# loyalty program design,
#
# subscription/membership tiers,
#
# seasonal & time-based promos,
#
# “perfect pair” marketing campaign.

# %%
import sqlite3

db_path = f"{base_path}dannys_pizza.sqlite"
conn = sqlite3.connect(db_path)
c = conn.cursor()

# drop existing tables (clean slate)
for t in [
    'pizza_names','pizza_toppings','pizza_recipes',
    'runners','customer_orders','runner_orders'
]:
    c.execute(f"DROP TABLE IF EXISTS {t};")

# create empty tables with the canonical column names
c.execute("""CREATE TABLE pizza_names (
  pizza_id INTEGER,
  pizza_name TEXT
);""")

c.execute("""CREATE TABLE pizza_toppings (
  topping_id INTEGER,
  topping_name TEXT
);""")

c.execute("""CREATE TABLE pizza_recipes (
  pizza_id INTEGER,
  toppings TEXT
);""")

c.execute("""CREATE TABLE runners (
  runner_id INTEGER,
  registration_date TEXT
);""")

# NOTE: keep your current column names exactly as they are in the DataFrame
# If your DF uses 'order_date', keep it; if it's 'order_time', keep that.
# Below uses 'order_date'—change to 'order_time' if that’s your DF.
c.execute("""CREATE TABLE customer_orders (
  order_id INTEGER,
  customer_id INTEGER,
  pizza_id INTEGER,
  exclusions TEXT,
  extras TEXT,
  order_date TEXT
);""")

c.execute("""CREATE TABLE runner_orders (
  order_id INTEGER,
  runner_id INTEGER,
  pickup_time TEXT,
  distance TEXT,
  duration TEXT,
  cancellation TEXT
);""")

conn.commit()

# append DataFrames exactly as-is (no cleaning)
pizza_names.to_sql('pizza_names', conn, if_exists='append', index=False)
pizza_toppings.to_sql('pizza_toppings', conn, if_exists='append', index=False)
pizza_recipes.to_sql('pizza_recipes', conn, if_exists='append', index=False)
runners.to_sql('runners', conn, if_exists='append', index=False)
customer_orders.to_sql('customer_orders', conn, if_exists='append', index=False)
runner_orders.to_sql('runner_orders', conn, if_exists='append', index=False)

conn.commit()
print("SQLite ready at:", db_path)
# Out:
# SQLite ready at: /content/dannys_pizza.sqlite

# %% [markdown]
# ##### Pizza Metrics

# %% [markdown]
# * ¿Cuántas pizzas fueron ordenadas?

# %%
pd.read_sql("""
SELECT COUNT(*) AS total_pizzas
FROM customer_orders;
""", conn)
# Out:
#    total_pizzas
# 0          2101

# %% [markdown]
# * ¿Cuántos pedidos únicos de clientes?

# %%
pd.read_sql("""
SELECT COUNT(DISTINCT order_id) AS unique_orders
FROM customer_orders;
""", conn)
# Out:
#    unique_orders
# 0           1500

# %% [markdown]
# * ¿Cuántos pedidos exitosos por repartidor?

# %%
pd.read_sql("""
SELECT runner_id,
       COUNT(runner_id) AS order_count
FROM runner_orders
WHERE distance IS NOT NULL
  AND TRIM(distance) <> ''
  AND cancellation = ''
GROUP BY runner_id
ORDER BY order_count DESC;
""", conn)
# Out:
# Empty DataFrame
# Columns: [runner_id, order_count]
# Index: []

# %% [markdown]
# Notice how our query returned empty results? That is a clue something is off in our filter. We wrote
# WHERE distance IS NOT NULL
#   AND cancellation = ''''
#
#   but in this dataset, the cancellation column does not only use a blank string to mean no cancellation. Sometimes it has the literal word 'null', sometimes it is NULL (the SQL null value), sometimes different casing (Null, NULL). Because of that, our =  condition excluded almost everything.

# %%
pd.read_sql("""
SELECT DISTINCT TRIM(cancellation) AS cancellation_value,
       COUNT(*) AS n
FROM runner_orders
GROUP BY 1
ORDER BY n DESC;
""", conn)
# Out:
#      cancellation_value     n
# 0                  None  1450
# 1         address issue    13
# 2      customer no show     9
# 3           runner sick     7
# 4            order late     7
# 5        custmer_no_sho     7
# 6    runner_unavailable     5
# 7  restaurant_cancelled     2

# %%
# 3a) Successful orders delivered by each runner (ignore distance presence)
pd.read_sql("""
SELECT runner_id,
       COUNT(*) AS order_count
FROM runner_orders
WHERE COALESCE(TRIM(LOWER(cancellation)),'') IN ('', 'null')
GROUP BY runner_id
ORDER BY order_count DESC;
""", conn)
# Out:
#     runner_id  order_count
# 0           3          115
# 1          14          112
# 2           2          110
# 3           5          109
# 4           7          101
# 5          12           96
# 6          11           96
# 7           1           93
# 8           8           92
# 9          13           91
# 10          4           90
# 11         15           89
# 12         10           89
# 13          9           87
# 14          6           80

# %% [markdown]
# * ¿Cuántas de cada tipo de pizza fueron entregadas?

# %%
pd.read_sql("""
    SELECT pizza_id,
           COUNT(*) AS delivered_count
    FROM customer_orders
    WHERE order_id IN (
        SELECT order_id
        FROM runner_orders
        WHERE COALESCE(TRIM(LOWER(cancellation)), '') IN ('', 'null')
    )
    GROUP BY pizza_id
    ORDER BY delivered_count DESC;
""", conn)
# Out:
#    pizza_id  delivered_count
# 0         3              451
# 1         6              385
# 2         2              328
# 3         4              271
# 4         1              226
# 5         5              207
# 6         7              158

# %% [markdown]
# * ¿Cuántas pizzas Vegetarian y Meatlovers se pidieron por cliente?

# %%
pd.read_sql("""
    SELECT customer_id,
           SUM(CASE WHEN pizza_id=2 THEN 1 ELSE 0 END) AS vegetarian_count,
           SUM(CASE WHEN pizza_id=3 THEN 1 ELSE 0 END) AS meatlovers_count
    FROM customer_orders
    WHERE order_id IN (
        SELECT order_id
        FROM runner_orders
        WHERE COALESCE(TRIM(LOWER(cancellation)), '') IN ('', 'null')
    )
    GROUP BY customer_id;
""", conn)
# Out:
#      customer_id  vegetarian_count  meatlovers_count
# 0              1                 0                 1
# 1              2                 0                 1
# 2              3                 0                 1
# 3              4                 0                 0
# 4              5                 4                 7
# ..           ...               ...               ...
# 552          791                 1                 0
# 553          793                 0                 1
# 554          794                 0                 0
# 555          796                 2                 0
# 556          798                 1                 0
#
# [557 rows x 3 columns]

# %% [markdown]
# * ¿Cuál fue el máximo número de pizzas entregadas en un solo pedido?

# %%
pd.read_sql("""
    SELECT order_id,
           COUNT(*) AS pizzas_in_order
    FROM customer_orders
    WHERE order_id IN (
        SELECT order_id
        FROM runner_orders
        WHERE COALESCE(TRIM(LOWER(cancellation)), '') IN ('', 'null')
    )
    GROUP BY order_id
    ORDER BY pizzas_in_order DESC
    LIMIT 1;
""", conn)
# Out:
#    order_id  pizzas_in_order
# 0      2441                4

# %% [markdown]
# * Para cada cliente, ¿cuántas pizzas entregadas tuvieron al menos un cambio y cuántas no tuvieron cambios?

# %%
pd.read_sql("""
    SELECT customer_id,
           SUM(CASE WHEN (TRIM(exclusions) <> '' OR TRIM(extras) <> '') THEN 1 ELSE 0 END) AS pizzas_with_changes,
           SUM(CASE WHEN (TRIM(exclusions) = '' AND TRIM(extras) = '') THEN 1 ELSE 0 END) AS pizzas_without_changes
    FROM customer_orders
    WHERE order_id IN (
        SELECT order_id
        FROM runner_orders
        WHERE COALESCE(TRIM(LOWER(cancellation)), '') IN ('', 'null')
    )
    GROUP BY customer_id;
""", conn)
# Out:
#      customer_id  pizzas_with_changes  pizzas_without_changes
# 0              1                    0                       0
# 1              2                    2                       0
# 2              3                    0                       0
# 3              4                    1                       0
# 4              5                   12                       0
# ..           ...                  ...                     ...
# 552          791                    0                       0
# 553          793                    1                       0
# 554          794                    1                       0
# 555          796                    2                       0
# 556          798                    1                       0
#
# [557 rows x 3 columns]

# %% [markdown]
# * ¿Cuántas pizzas entregadas tuvieron tanto exclusiones como extras?

# %%
pd.read_sql("""
    SELECT COUNT(*) AS pizzas_with_exclusions_and_extras
    FROM customer_orders
    WHERE order_id IN (
        SELECT order_id
        FROM runner_orders
        WHERE COALESCE(TRIM(LOWER(cancellation)), '') IN ('', 'null')
    )
      AND TRIM(exclusions) <> ''
      AND TRIM(extras) <> '';
""", conn)
# Out:
#    pizzas_with_exclusions_and_extras
# 0                                192

# %% [markdown]
# * ¿Cuál fue el volumen total de pizzas ordenadas por cada hora del día?

# %%
pd.read_sql("""
    SELECT strftime('%H', order_date) AS hour,
           COUNT(*) AS pizzas_ordered
    FROM customer_orders
    WHERE order_id IN (
        SELECT order_id
        FROM runner_orders
        WHERE COALESCE(TRIM(LOWER(cancellation)), '') IN ('', 'null')
    )
    GROUP BY hour
    ORDER BY hour;
""", conn)
# Out:
#    hour  pizzas_ordered
# 0    00              64
# 1    01              38
# 2    02              48
# 3    03              58
# 4    04              54
# 5    05              28
# 6    06              72
# 7    07              32
# 8    08              43
# 9    09              64
# 10   10              33
# 11   11              39
# 12   12              34
# 13   13              51
# 14   14              53
# 15   15              83
# 16   16             134
# 17   17             192
# 18   18             259
# 19   19             280
# 20   20             197
# 21   21              98
# 22   22              36
# 23   23              36

# %% [markdown]
# * ¿Cuál fue el volumen de pedidos por cada día de la semana?

# %%
pd.read_sql("""
    SELECT strftime('%w', order_date) AS weekday,
           COUNT(*) AS pizzas_ordered
    FROM customer_orders
    WHERE order_id IN (
        SELECT order_id
        FROM runner_orders
        WHERE COALESCE(TRIM(LOWER(cancellation)), '') IN ('', 'null')
    )
    GROUP BY weekday
    ORDER BY weekday;
""", conn)
# Out:
#   weekday  pizzas_ordered
# 0       0             426
# 1       1             167
# 2       2             168
# 3       3             180
# 4       4             241
# 5       5             401
# 6       6             443

# %% [markdown]
# #### Runner and Customer Experience

# %% [markdown]
# 1. How many runners signed up for each 1 week period? (week starts 2021-01-01)

# %%
pd.read_sql("""
    SELECT strftime('%Y-%W', registration_date) AS week,
           COUNT(*) AS runners_signed_up
    FROM runners
    GROUP BY week
    ORDER BY week;
""", conn)
# Out:
#        week  runners_signed_up
# 0   2021-00                  1
# 1   2021-01                  1
# 2   2021-02                  1
# 3   2021-03                  1
# 4   2021-04                  1
# 5   2021-05                  1
# 6   2021-06                  1
# 7   2021-07                  1
# 8   2021-08                  1
# 9   2021-09                  1
# 10  2021-10                  1
# 11  2021-11                  1
# 12  2021-12                  1
# 13  2021-13                  1
# 14  2021-14                  1

# %% [markdown]
# 2. What was the average time in minutes it took for each runner to arrive at the Pizza Runner HQ to pickup the order?

# %%
pd.read_sql("""
    SELECT runner_id,
           AVG(CAST(strftime('%s', pickup_time) - strftime('%s', order_date) AS REAL)/60.0) AS avg_arrival_minutes
    FROM runner_orders
    JOIN customer_orders USING(order_id)
    WHERE COALESCE(TRIM(LOWER(cancellation)), '') IN ('', 'null')
      AND pickup_time IS NOT NULL
      AND order_date IS NOT NULL
    GROUP BY runner_id;
""", conn)
# Out:
#     runner_id  avg_arrival_minutes
# 0           1            13.142857
# 1           2            13.606897
# 2           3            13.341935
# 3           4            13.703704
# 4           5            13.790850
# 5           6            14.313043
# 6           7            12.977273
# 7           8            12.876033
# 8           9            13.500000
# 9          10            13.367521
# 10         11            13.111111
# 11         12            12.459854
# 12         13            14.106870
# 13         14            13.649351
# 14         15            12.860465

# %% [markdown]
# 3. Is there any relationship between the number of pizzas and how long the order takes to prepare?

# %%
pd.read_sql("""
    SELECT co.order_id,
           COUNT(*) AS pizzas_in_order,
           ro.duration
    FROM customer_orders co
    JOIN runner_orders ro ON co.order_id = ro.order_id
    WHERE COALESCE(TRIM(LOWER(ro.cancellation)), '') IN ('', 'null')
      AND ro.duration IS NOT NULL
    GROUP BY co.order_id, ro.duration
    ORDER BY pizzas_in_order DESC;
""", conn)
# Out:
#       order_id  pizzas_in_order    duration
# 0         1106                4  19 minutes
# 1         1204                4  16 minutes
# 2         1331                4  15 minutes
# 3         1401                4   8 minutes
# 4         1752                4  17 minutes
# ...        ...              ...         ...
# 1390      2492                1   7 minutes
# 1391      2493                1  14 minutes
# 1392      2494                1  29 minutes
# 1393      2495                1  18 minutes
# 1394      2496                1  10 minutes
#
# [1395 rows x 3 columns]

# %% [markdown]
# #### Customer & business intelligence

# %% [markdown]
# C1. Total customer spend

# %%
pd.read_sql("""
    SELECT customer_id,
           COUNT(*) AS pizzas_ordered
    FROM customer_orders
    WHERE order_id IN (
        SELECT order_id
        FROM runner_orders
        WHERE COALESCE(TRIM(LOWER(cancellation)), '') IN ('', 'null')
    )
    GROUP BY customer_id
    ORDER BY pizzas_ordered DESC;
""", conn)
# Out:
#      customer_id  pizzas_ordered
# 0            620              52
# 1             30              52
# 2            717              51
# 3            657              51
# 4            500              50
# ..           ...             ...
# 552           10               1
# 553            8               1
# 554            7               1
# 555            4               1
# 556            3               1
#
# [557 rows x 2 columns]

# %% [markdown]
# C2. Customer frequency (distinct days of orders)

# %%
pd.read_sql("""
    SELECT customer_id,
           COUNT(DISTINCT DATE(order_date)) AS order_days
    FROM customer_orders
    WHERE order_id IN (
        SELECT order_id
        FROM runner_orders
        WHERE COALESCE(TRIM(LOWER(cancellation)), '') IN ('', 'null')
    )
    GROUP BY customer_id
    ORDER BY order_days DESC;
""", conn)
# Out:
#      customer_id  order_days
# 0            717          35
# 1             30          35
# 2            730          33
# 3            657          32
# 4            620          32
# ..           ...         ...
# 552            8           1
# 553            7           1
# 554            4           1
# 555            3           1
# 556            2           1
#
# [557 rows x 2 columns]

# %% [markdown]
# C3. First pizza ordered by each customer

# %%
pd.read_sql("""
    SELECT customer_id,
           MIN(order_date) AS first_order_date,
           pizza_id
    FROM customer_orders
    WHERE order_id IN (
        SELECT order_id
        FROM runner_orders
        WHERE COALESCE(TRIM(LOWER(cancellation)), '') IN ('', 'null')
    )
    GROUP BY customer_id
    ORDER BY first_order_date;
""", conn)
# Out:
#      customer_id     first_order_date  pizza_id
# 0            500  2024-11-01 04:07:33         5
# 1            464  2024-11-01 14:29:31         6
# 2            319  2024-11-01 16:21:41         3
# 3            708  2024-11-01 18:28:31         2
# 4            438  2024-11-01 19:02:29         6
# ..           ...                  ...       ...
# 552          296  2025-08-09 18:17:37         6
# 553          401  2025-08-10 16:39:24         3
# 554           24  2025-08-10 22:29:27         3
# 555           74  2025-08-14 00:15:44         5
# 556          247  2025-08-14 19:42:21         1
#
# [557 rows x 3 columns]

# %% [markdown]
# C4. Overall best-seller pizza

# %%
pd.read_sql("""
    SELECT pn.pizza_id,
           pn.pizza_name,
           COUNT(*) AS total_sold
    FROM customer_orders co
    JOIN pizza_names pn ON co.pizza_id = pn.pizza_id
    WHERE co.order_id IN (
        SELECT order_id
        FROM runner_orders
        WHERE COALESCE(TRIM(LOWER(cancellation)), '') IN ('', 'null')
    )
    GROUP BY pn.pizza_id, pn.pizza_name
    ORDER BY total_sold DESC;
""", conn)
# Out:
#    pizza_id    pizza_name  total_sold
# 0         3   Meat Lovers         451
# 1         6     Pepperoni         385
# 2         2    Vegetarian         328
# 3         4   BBQ Chicken         271
# 4         1    Margherita         226
# 5         5      Hawaiian         207
# 6         7  Vegan Veggie         158

# %% [markdown]
# C5. Most popular pizza by customer

# %%
pd.read_sql("""
    SELECT customer_id,
           pizza_id,
           COUNT(*) AS times_ordered
    FROM customer_orders
    WHERE order_id IN (
        SELECT order_id
        FROM runner_orders
        WHERE COALESCE(TRIM(LOWER(cancellation)), '') IN ('', 'null')
    )
    GROUP BY customer_id, pizza_id
    ORDER BY customer_id, times_ordered DESC;
""", conn)
# Out:
#       customer_id  pizza_id  times_ordered
# 0               1         6              1
# 1               1         4              1
# 2               1         3              1
# 3               2         3              1
# 4               2         1              1
# ...           ...       ...            ...
# 1185          793         3              1
# 1186          794         6              2
# 1187          796         2              2
# 1188          796         1              1
# 1189          798         2              1
#
# [1190 rows x 3 columns]

# %% [markdown]
# C6. Regulars with ≥30 orders and their go-to pizzas

# %%
pd.read_sql("""
    SELECT customer_id,
           pizza_id,
           COUNT(*) AS pizza_count
    FROM customer_orders
    WHERE order_id IN (
        SELECT order_id
        FROM runner_orders
        WHERE COALESCE(TRIM(LOWER(cancellation)), '') IN ('', 'null')
    )
    GROUP BY customer_id, pizza_id
    HAVING customer_id IN (
        SELECT customer_id
        FROM customer_orders
        WHERE order_id IN (
            SELECT order_id
            FROM runner_orders
            WHERE COALESCE(TRIM(LOWER(cancellation)), '') IN ('', 'null')
        )
        GROUP BY customer_id
        HAVING COUNT(*) >= 30
    )
      AND COUNT(*) = (
        SELECT MAX(cnt)
        FROM (
            SELECT customer_id, pizza_id, COUNT(*) AS cnt
            FROM customer_orders
            WHERE order_id IN (
                SELECT order_id
                FROM runner_orders
                WHERE COALESCE(TRIM(LOWER(cancellation)), '') IN ('', 'null')
            )
            GROUP BY customer_id, pizza_id
        )
        WHERE customer_id = customer_orders.customer_id
    )
    ORDER BY pizza_count DESC;
""", conn)
# Out:
#     customer_id  pizza_id  pizza_count
# 0           657         3           18
# 1            30         6           15
# 2           180         3           15
# 3           620         6           14
# 4           717         6           13
# 5           500         3           12
# 6           730         2           12
# 7            45         6           11
# 8           228         2           11
# 9           240         6           11
# 10          755         2           11
# 11          400         6           10
# 12          547         2           10
# 13          547         6           10
# 14          667         3           10
# 15          463         2            9
# 16          543         3            8
# 17          698         2            8
# 18          698         6            8
# 19            5         3            7

# %% [markdown]
# C7. Customers with very consistent habits

# %%
pd.read_sql("""
    SELECT customer_id,
           COUNT(DISTINCT pizza_id) AS unique_pizzas,
           COUNT(*) AS total_orders
    FROM customer_orders
    WHERE order_id IN (
        SELECT order_id
        FROM runner_orders
        WHERE COALESCE(TRIM(LOWER(cancellation)), '') IN ('', 'null')
    )
    GROUP BY customer_id
    HAVING unique_pizzas = 1 AND total_orders > 1
    ORDER BY total_orders DESC;
""", conn)
# Out:
#     customer_id  unique_pizzas  total_orders
# 0            94              1             3
# 1           794              1             2
# 2           715              1             2
# 3           697              1             2
# 4           537              1             2
# 5           526              1             2
# 6           522              1             2
# 7           521              1             2
# 8           485              1             2
# 9           464              1             2
# 10          343              1             2
# 11          303              1             2
# 12          302              1             2
# 13          250              1             2
# 14          241              1             2
# 15          231              1             2
# 16          229              1             2
# 17          182              1             2
# 18          170              1             2
# 19          151              1             2
# 20          127              1             2
# 21           69              1             2
# 22           65              1             2
# 23           27              1             2
# 24           22              1             2

# %% [markdown]
# C8. “Perfect pair” — Find pairs of customers who always order together and the same pizza

# %%
pd.read_sql("""
    SELECT c1.customer_id AS customer1,
           c2.customer_id AS customer2,
           COUNT(*) AS shared_orders
    FROM customer_orders c1
    JOIN customer_orders c2
      ON c1.order_id = c2.order_id
     AND c1.customer_id < c2.customer_id
     AND c1.pizza_id = c2.pizza_id
    WHERE c1.order_id IN (
        SELECT order_id
        FROM runner_orders
        WHERE COALESCE(TRIM(LOWER(cancellation)), '') IN ('', 'null')
    )
    GROUP BY customer1, customer2
    HAVING COUNT(*) = (
        SELECT COUNT(*)
        FROM customer_orders
        WHERE customer_id = customer1
          AND order_id IN (
              SELECT order_id
              FROM runner_orders
              WHERE COALESCE(TRIM(LOWER(cancellation)), '') IN ('', 'null')
          )
    )
       AND COUNT(*) = (
        SELECT COUNT(*)
        FROM customer_orders
        WHERE customer_id = customer2
          AND order_id IN (
              SELECT order_id
              FROM runner_orders
              WHERE COALESCE(TRIM(LOWER(cancellation)), '') IN ('', 'null')
          )
    )
    ORDER BY shared_orders DESC;
""", conn)
# Out:
# Empty DataFrame
# Columns: [customer1, customer2, shared_orders]
# Index: []

# %%
pd.read_sql("""
    SELECT
        c1.customer_id AS customer1,
        c2.customer_id AS customer2,
        c1.pizza_id,
        pn.pizza_name,
        COUNT(*) AS similar_pizzas
    FROM customer_orders c1
    JOIN customer_orders c2
      ON c1.pizza_id = c2.pizza_id
     AND c1.customer_id < c2.customer_id
    JOIN pizza_names pn ON c1.pizza_id = pn.pizza_id
    WHERE c1.order_id IN (
        SELECT order_id
        FROM runner_orders
        WHERE COALESCE(TRIM(LOWER(cancellation)), '') IN ('', 'null')
    )
      AND c2.order_id IN (
        SELECT order_id
        FROM runner_orders
        WHERE COALESCE(TRIM(LOWER(cancellation)), '') IN ('', 'null')
    )
    GROUP BY customer1, customer2, c1.pizza_id, pn.pizza_name
    HAVING similar_pizzas >= 2
    ORDER BY similar_pizzas DESC
    LIMIT 15;
""", conn)
# Out:
#     customer1  customer2  pizza_id   pizza_name  similar_pizzas
# 0         180        657         3  Meat Lovers             270
# 1         500        657         3  Meat Lovers             216
# 2         657        717         3  Meat Lovers             216
# 3          30        620         6    Pepperoni             210
# 4          30        717         6    Pepperoni             195
# 5         620        717         6    Pepperoni             182
# 6         180        500         3  Meat Lovers             180
# 7         180        717         3  Meat Lovers             180
# 8         657        667         3  Meat Lovers             180
# 9          30         45         6    Pepperoni             165
# 10         30        240         6    Pepperoni             165
# 11        657        755         3  Meat Lovers             162
# 12         45        620         6    Pepperoni             154
# 13        240        620         6    Pepperoni             154
# 14         30        400         6    Pepperoni             150

# %% [markdown]
# C9. Peak order times

# %%
pd.read_sql("""
    SELECT strftime('%w', order_date) AS weekday,
           strftime('%H', order_date) AS hour,
           COUNT(*) AS pizzas_ordered
    FROM customer_orders
    WHERE order_id IN (
        SELECT order_id
        FROM runner_orders
        WHERE COALESCE(TRIM(LOWER(cancellation)), '') IN ('', 'null')
    )
    GROUP BY weekday, hour
    ORDER BY weekday, hour;
""", conn)
# Out:
#     weekday hour  pizzas_ordered
# 0         0   00              12
# 1         0   01               7
# 2         0   02               1
# 3         0   03              18
# 4         0   04               7
# ..      ...  ...             ...
# 159       6   19              66
# 160       6   20              28
# 161       6   21              20
# 162       6   22               8
# 163       6   23               9
#
# [164 rows x 3 columns]

# %% [markdown]
# C10. Best candidates for loyalty program

# %%
pd.read_sql("""
    SELECT customer_id,
           COUNT(*) AS total_orders,
           COUNT(DISTINCT DATE(order_date)) AS order_days,
           COUNT(DISTINCT pizza_id) AS unique_pizzas
    FROM customer_orders
    WHERE order_id IN (
        SELECT order_id
        FROM runner_orders
        WHERE COALESCE(TRIM(LOWER(cancellation)), '') IN ('', 'null')
    )
    GROUP BY customer_id
    ORDER BY total_orders DESC, order_days DESC, unique_pizzas ASC
    LIMIT 10;
""", conn)
# Out:
#    customer_id  total_orders  order_days  unique_pizzas
# 0           30            52          35              7
# 1          620            52          32              7
# 2          717            51          35              7
# 3          657            51          32              7
# 4          500            50          32              7
# 5          730            49          33              7
# 6          180            49          30              7
# 7          240            47          30              7
# 8          547            46          29              7
# 9          755            44          30              7

# %% [markdown]
# ## Pyspark

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("DannysPizza").getOrCreate()

pizza_names = spark.read.csv(base_path + "pizza_names.csv", header=True, inferSchema=True)
pizza_toppings = spark.read.csv(base_path + "pizza_toppings.csv", header=True, inferSchema=True)
pizza_recipes = spark.read.csv(base_path + "pizza_recipes.csv", header=True, inferSchema=True)
customer_orders = spark.read.csv(base_path + "customer_orders.csv", header=True, inferSchema=True)
runner_orders = spark.read.csv(base_path + "runner_orders.csv", header=True, inferSchema=True)
runners = spark.read.csv(base_path + "runners.csv", header=True, inferSchema=True)

# %% [markdown]
# Número de órdenes por cliente

# %%
customer_orders.groupBy("customer_id").count().orderBy("count", ascending=False).show()
# Out:
# +-----------+-----+
# |customer_id|count|
# +-----------+-----+
# |        620|   58|
# |        500|   54|
# |        730|   53|
# |        657|   52|
# |         30|   52|
# |        717|   51|
# |        547|   49|
# |        180|   49|
# |        240|   47|
# |         45|   45|
# |        755|   44|
# |        667|   41|
# |        228|   41|
# |        463|   39|
# |        400|   37|
# |        698|   35|
# |        543|   34|
# |          5|   32|
# |        566|    8|
# |        177|    8|
# +-----------+-----+
# only showing top 20 rows

# %% [markdown]
# Pizzas más pedidas

# %%
from pyspark.sql.functions import col

customer_orders.groupBy("pizza_id").count().join(
    pizza_names, on="pizza_id"
).orderBy(col("count").desc()).show()
# Out:
# +--------+-----+------------+
# |pizza_id|count|  pizza_name|
# +--------+-----+------------+
# |       3|  468| Meat Lovers|
# |       6|  398|   Pepperoni|
# |       2|  340|  Vegetarian|
# |       4|  278| BBQ Chicken|
# |       1|  235|  Margherita|
# |       5|  218|    Hawaiian|
# |       7|  164|Vegan Veggie|
# +--------+-----+------------+

# %% [markdown]
# Runners con más entregas exitosas

# %%
runner_orders.filter(col("cancellation").isNull()) \
    .groupBy("runner_id").count().join(runners, "runner_id") \
    .orderBy("count", ascending=False).show()
# Out:
# +---------+-----+-----------------+
# |runner_id|count|registration_date|
# +---------+-----+-----------------+
# |        3|  115|       2021-01-17|
# |       14|  112|       2021-04-04|
# |        2|  110|       2021-01-10|
# |        5|  109|       2021-01-31|
# |        7|  101|       2021-02-14|
# |       12|   96|       2021-03-21|
# |       11|   96|       2021-03-14|
# |        1|   93|       2021-01-03|
# |        8|   92|       2021-02-21|
# |       13|   91|       2021-03-28|
# |        4|   90|       2021-01-24|
# |       15|   89|       2021-04-11|
# |       10|   89|       2021-03-07|
# |        9|   87|       2021-02-28|
# |        6|   80|       2021-02-07|
# +---------+-----+-----------------+

# %% [markdown]
# Toppings más frecuentes en pedidos personalizados

# %%
customized_orders = customer_orders.withColumn("topping_id", explode(split("exclusions", ",")))
customized_orders.groupBy("topping_id").count() \
    .join(pizza_toppings, "topping_id") \
    .orderBy(col("count").desc()).show()
# Out:
# +----------+-----+------------+
# |topping_id|count|topping_name|
# +----------+-----+------------+
# |         1|  166|Tomato Sauce|
# |         2|  155|  Mozzarella|
# |         7|   66|   Pepperoni|
# |         6|   39|      Olives|
# |         9|   36|        Beef|
# |         5|   33| Bell Pepper|
# |        14|   30| Fresh Basil|
# |         8|   29|       Bacon|
# |        10|   26|     Chicken|
# |         4|   26|       Onion|
# |         3|   24|    Mushroom|
# |        11|   22|   Pineapple|
# |        12|   22|   BBQ Sauce|
# |        15|   10|      Garlic|
# +----------+-----+------------+

# %% [markdown]
# ### Regresión logistica

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("DannysPizza-LogReg").getOrCreate()

# Carga
orders = spark.read.csv("customer_orders.csv", header=True, inferSchema=True)
runner_orders = spark.read.csv("runner_orders.csv", header=True, inferSchema=True)
pizza_names = spark.read.csv("pizza_names.csv", header=True, inferSchema=True)
pizza_recipes = spark.read.csv("pizza_recipes.csv", header=True, inferSchema=True)
pizza_toppings = spark.read.csv("pizza_toppings.csv", header=True, inferSchema=True)
runners = spark.read.csv("runners.csv", header=True, inferSchema=True)

# %%
from pyspark.sql.functions import col, when, regexp_replace, trim, to_timestamp, hour, split, size, coalesce, lit

# Label: entregado (1) si no hay cancellation; cancelado (0) si sí hay
runner_orders = runner_orders.withColumn(
    "label", when(col("cancellation").isNull(), 1).otherwise(0)
)

# Limpieza numérica de distance (km) y duration (min)
runner_orders = (runner_orders
    .withColumn("distance_km", regexp_replace(trim(col("distance")), "km", "").cast("double"))
    .withColumn("duration_min", regexp_replace(trim(col("duration")), "minutes", "").cast("double"))
)

# Tiempos
runner_orders = runner_orders.withColumn("pickup_ts", to_timestamp("pickup_time"))
orders = orders.withColumn("order_ts", to_timestamp("order_date"))

# Derivados útiles del pedido
# - cuenta de exclusiones / extras (cuando vienen como "1,2,3")
orders = (orders
    .withColumn("n_exclusions", when(col("exclusions").isNull() | (trim(col("exclusions"))==""), 0)
                .otherwise(size(split(col("exclusions"), ","))))
    .withColumn("n_extras", when(col("extras").isNull() | (trim(col("extras"))==""), 0)
                .otherwise(size(split(col("extras"), ","))))
)

# Un pedido puede tener varias pizzas; derivamos cantidad por order_id
from pyspark.sql.window import Window
from pyspark.sql.functions import count as f_count

w = Window.partitionBy("order_id")
orders = orders.withColumn("pizzas_in_order", f_count(lit(1)).over(w))

# Hora del día (útil como proxy de demanda)
orders = orders.withColumn("order_hour", hour(col("order_ts")))

# %%
# Join runner_orders con orders por order_id
data = (runner_orders.join(orders, on="order_id", how="inner")
        .join(pizza_names, on="pizza_id", how="left")
        .join(runners, on="runner_id", how="left"))

# Selección de columnas de entrada
# Numéricas: distance_km, duration_min
# Derivadas de pedido: pizzas_in_order, n_exclusions, n_extras, order_hour
# Categóricas: runner_id, pizza_id
# (ajusta según lo que realmente tengas)
feature_cols_num = ["distance_km", "duration_min", "pizzas_in_order", "n_exclusions", "n_extras", "order_hour"]
cat_cols = ["runner_id", "pizza_id"]

# %%
from pyspark.ml.feature import StringIndexer, OneHotEncoder, VectorAssembler

# Indexers para categóricas
idx_stages = [
    StringIndexer(inputCol=c, outputCol=f"{c}_idx", handleInvalid="keep")
    for c in cat_cols
]

# One-hot
oh = OneHotEncoder(inputCols=[f"{c}_idx" for c in cat_cols],
                   outputCols=[f"{c}_oh" for c in cat_cols],
                   handleInvalid="keep")

# Ensamblador
assembler = VectorAssembler(
    inputCols=feature_cols_num + [f"{c}_oh" for c in cat_cols],
    outputCol="features",
    handleInvalid="keep"
)

# %%
from pyspark.ml.classification import LogisticRegression
from pyspark.ml import Pipeline

lr = LogisticRegression(
    featuresCol="features", labelCol="label",
    maxIter=100, regParam=0.0, elasticNetParam=0.0
)

pipeline = Pipeline(stages=idx_stages + [oh, assembler, lr])

# %%
train, test = data.dropna(subset=["label"]).randomSplit([0.8, 0.2], seed=42)

# Drop rows with NaN values in the feature columns
train = train.dropna(subset=feature_cols_num)

model = pipeline.fit(train)
pred = model.transform(test)
pred.select("order_id", "label", "probability", "prediction").show(10, truncate=False)
# Out:
# +--------+-----+-----------+----------+
# |order_id|label|probability|prediction|
# +--------+-----+-----------+----------+
# |1216    |1    |[0.0,1.0]  |1.0       |
# |1794    |1    |[0.0,1.0]  |1.0       |
# |1994    |1    |[0.0,1.0]  |1.0       |
# |2414    |1    |[0.0,1.0]  |1.0       |
# |1191    |1    |[0.0,1.0]  |1.0       |
# |1460    |1    |[0.0,1.0]  |1.0       |
# |2182    |1    |[0.0,1.0]  |1.0       |
# |1192    |1    |[0.0,1.0]  |1.0       |
# |1567    |1    |[0.0,1.0]  |1.0       |
# |1575    |1    |[0.0,1.0]  |1.0       |
# +--------+-----+-----------+----------+
# only showing top 10 rows

# %%
from pyspark.ml.evaluation import BinaryClassificationEvaluator, MulticlassClassificationEvaluator

e_roc = BinaryClassificationEvaluator(labelCol="label", rawPredictionCol="rawPrediction", metricName="areaUnderROC")
e_pr  = BinaryClassificationEvaluator(labelCol="label", rawPredictionCol="rawPrediction", metricName="areaUnderPR")
e_acc = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="accuracy")

print("AUC ROC:", e_roc.evaluate(pred))
print("AUC PR :", e_pr.evaluate(pred))
print("Accuracy:", e_acc.evaluate(pred))
# Out:
# AUC ROC: 0.5
# AUC PR : 0.9731182795698925
# Accuracy: 0.9731182795698925
